# %%
import pandas as pd
df_1 = pd.read_csv('..\data\deneme_1 Liverpool.csv')
df_1
# Out:
#     player_id first_name         last_name  age nation  mp  starts    Mt  \
# 0           1    Allison            Becker   31    BRA  21      21  1890
# 1           2     Virgil          Van Dijk   32    NED  23      23  2007
# 2           3    Mohamed             Salah   31    EGY  21      20  1786
# 3           4    Dominik        Szoboszlai   23    HUN  21      20  1657
# 4           5      Trent  Alexander-Arnold   25    ENG  21      19  1622
# 5           6       Luis              Diaz   27    COL  24      19  1568
# 6           7     Alexis      Mac Allister   25    ARG  20      19  1541
# 7           8     Darwin             Nunez   24    URU  24      16  1465
# 8           9   Ibrahima            Konate   24    FRA  18      13  1242
# 9          10      Diogo              Jota   27    POR  19      13  1047
# 10         11     Curtis             Jones   23    ENG  17      12   956
# 11         12        Joe             Gomez   26    ENG  21      11  1182
# 12         13       Cody             Gakpo   24    NED  23      10   975
# 13         14     Andrew         Robertson   29    SCO  12      10   954
# 14         15     Wataru              Endo   31    JPN  17      10   883
# 15         16       Joel             Matip   32    CMR  10       9   781
# 16         17       Ryan       Gravenberch   21    NED  18       8   768
# 17         18     Kostas          Tsimikas   27    GRE  11       8   665
# 18         19   Caoimhin          Kelleher   25    IRL   4       4   360
# 19         20     Jarell           Quansah   21    ENG   7       4   353
# 20         21     Harvey           Elliott   20    ENG  21       3   583
# 21         22      Conor           Bradley   20    NIR   3       3   231
# 22         23      Bobby             Clark   19    ENG   3       0    17
# 23         24        Ben              Doak   18    SCO   1       0    14
# 24         25       Owen              Beck   21    WAL   1       0     8
# 25         26     Thiago         Alcantara   32    ESP   1       0     6
# 26         27      James          McConell   19    ENG   2       0     2
# 27         28      Kaide            Gordon   19    ENG   1       0     1
# 28         29     Adrian          Castillo   37    ESP   0       0     0
# 29         30     Stefan          Bajcetic   19    ESP   0       0     0
# 30         31       Luke          Chambers   19    ENG   0       0     0
# 31         32      Lewis            Koumas   18    WAL   0       0     0
# 32         33     Fabian            Mrozek   20    POL   0       0     0
# 33         34       Trey             Nyoni   16    ENG   0       0     0
# 34         35    Marcelo          Pitaluga   21    BRA   0       0     0
# 35         36      Calum           Scanlon   19    ENG   0       0     0
#
#     full_match  goals  assist    pos
# 0           21      0       0     GK
# 1           22      1       2     DF
# 2           20     15       9     FW
# 3           18      3       2     MF
# 4           18      2       4     DF
# 5           17      5       3     FW
# 6           17      2       1     MF
# 7           16      9       7     FW
# 8           14      0       0     DF
# 9           12      9       3     FW
# 10          11      1       1     MF
# 11          13      0       1     DF
# 12          11      4       3  FW,MF
# 13          11      1       0     DF
# 14          10      1       0     MF
# 15           9      0       0     DF
# 16           9      0       0     MF
# 17           7      0       3     DF
# 18           4      0       0     GK
# 19           4      0       0     DF
# 20           7      1       2  MF,FW
# 21           3      1       3     DF
# 22           0      0       0     MF
# 23           0      0       0     FW
# 24           0      0       0     DF
# 25           0      0       0     MF
# 26           0      0       0     MF
# 27           0      0       0     FW
# 28           0      0       0     GK
# 29           0      0       0     DF
# 30           0      0       0     DF
# 31           0      0       0     MF
# 32           0      0       0     GK
# 33           0      0       0     MF
# 34           0      0       0     GK
# 35           0      0       0     MF

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from jupyterthemes.jtplot import figsize

# %%
pd.read_csv('../data/deneme_1 Liverpool.csv')
# Out:
#     player_id first_name         last_name  age nation  mp  starts    Mt  \
# 0           1    Allison            Becker   31    BRA  21      21  1890
# 1           2     Virgil          Van Dijk   32    NED  23      23  2007
# 2           3    Mohamed             Salah   31    EGY  21      20  1786
# 3           4    Dominik        Szoboszlai   23    HUN  21      20  1657
# 4           5      Trent  Alexander-Arnold   25    ENG  21      19  1622
# 5           6       Luis              Diaz   27    COL  24      19  1568
# 6           7     Alexis      Mac Allister   25    ARG  20      19  1541
# 7           8     Darwin             Nunez   24    URU  24      16  1465
# 8           9   Ibrahima            Konate   24    FRA  18      13  1242
# 9          10      Diogo              Jota   27    POR  19      13  1047
# 10         11     Curtis             Jones   23    ENG  17      12   956
# 11         12        Joe             Gomez   26    ENG  21      11  1182
# 12         13       Cody             Gakpo   24    NED  23      10   975
# 13         14     Andrew         Robertson   29    SCO  12      10   954
# 14         15     Wataru              Endo   31    JPN  17      10   883
# 15         16       Joel             Matip   32    CMR  10       9   781
# 16         17       Ryan       Gravenberch   21    NED  18       8   768
# 17         18     Kostas          Tsimikas   27    GRE  11       8   665
# 18         19   Caoimhin          Kelleher   25    IRL   4       4   360
# 19         20     Jarell           Quansah   21    ENG   7       4   353
# 20         21     Harvey           Elliott   20    ENG  21       3   583
# 21         22      Conor           Bradley   20    NIR   3       3   231
# 22         23      Bobby             Clark   19    ENG   3       0    17
# 23         24        Ben              Doak   18    SCO   1       0    14
# 24         25       Owen              Beck   21    WAL   1       0     8
# 25         26     Thiago         Alcantara   32    ESP   1       0     6
# 26         27      James          McConell   19    ENG   2       0     2
# 27         28      Kaide            Gordon   19    ENG   1       0     1
# 28         29     Adrian          Castillo   37    ESP   0       0     0
# 29         30     Stefan          Bajcetic   19    ESP   0       0     0
# 30         31       Luke          Chambers   19    ENG   0       0     0
# 31         32      Lewis            Koumas   18    WAL   0       0     0
# 32         33     Fabian            Mrozek   20    POL   0       0     0
# 33         34       Trey             Nyoni   16    ENG   0       0     0
# 34         35    Marcelo          Pitaluga   21    BRA   0       0     0
# 35         36      Calum           Scanlon   19    ENG   0       0     0
#
#     full_match  goals  assist    pos
# 0           21      0       0     GK
# 1           22      1       2     DF
# 2           20     15       9     FW
# 3           18      3       2     MF
# 4           18      2       4     DF
# 5           17      5       3     FW
# 6           17      2       1     MF
# 7           16      9       7     FW
# 8           14      0       0     DF
# 9           12      9       3     FW
# 10          11      1       1     MF
# 11          13      0       1     DF
# 12          11      4       3  FW,MF
# 13          11      1       0     DF
# 14          10      1       0     MF
# 15           9      0       0     DF
# 16           9      0       0     MF
# 17           7      0       3     DF
# 18           4      0       0     GK
# 19           4      0       0     DF
# 20           7      1       2  MF,FW
# 21           3      1       3     DF
# 22           0      0       0     MF
# 23           0      0       0     FW
# 24           0      0       0     DF
# 25           0      0       0     MF
# 26           0      0       0     MF
# 27           0      0       0     FW
# 28           0      0       0     GK
# 29           0      0       0     DF
# 30           0      0       0     DF
# 31           0      0       0     MF
# 32           0      0       0     GK
# 33           0      0       0     MF
# 34           0      0       0     GK
# 35           0      0       0     MF

# %%
df_1.head()
# Out:
#    player_id first_name         last_name  age nation  mp  starts    Mt  \
# 0          1    Allison            Becker   31    BRA  21      21  1890
# 1          2     Virgil          Van Dijk   32    NED  23      23  2007
# 2          3    Mohamed             Salah   31    EGY  21      20  1786
# 3          4    Dominik        Szoboszlai   23    HUN  21      20  1657
# 4          5      Trent  Alexander-Arnold   25    ENG  21      19  1622
#
#    full_match  goals  assist pos
# 0          21      0       0  GK
# 1          22      1       2  DF
# 2          20     15       9  FW
# 3          18      3       2  MF
# 4          18      2       4  DF

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   player_id   36 non-null     int64
#  1   first_name  36 non-null     object
#  2   last_name   36 non-null     object
#  3   age         36 non-null     int64
#  4   nation      36 non-null     object
#  5   mp          36 non-null     int64
#  6   starts      36 non-null     int64
#  7   Mt          36 non-null     int64
#  8   full_match  36 non-null     int64
#  9   goals       36 non-null     int64
#  10  assist      36 non-null     int64
#  11  pos         36 non-null     object
# dtypes: int64(8), object(4)
# memory usage: 3.5+ KB

# %%
df_1.isnull().sum()
# Out:
# player_id     0
# first_name    0
# last_name     0
# age           0
# nation        0
# mp            0
# starts        0
# Mt            0
# full_match    0
# goals         0
# assist        0
# pos           0
# dtype: int64

# %%
df_1['attack_point'] = df_1['goals'] + df_1['assist']
df_1
# Out:
#     player_id first_name         last_name  age nation  mp  starts    Mt  \
# 0           1    Allison            Becker   31    BRA  21      21  1890
# 1           2     Virgil          Van Dijk   32    NED  23      23  2007
# 2           3    Mohamed             Salah   31    EGY  21      20  1786
# 3           4    Dominik        Szoboszlai   23    HUN  21      20  1657
# 4           5      Trent  Alexander-Arnold   25    ENG  21      19  1622
# 5           6       Luis              Diaz   27    COL  24      19  1568
# 6           7     Alexis      Mac Allister   25    ARG  20      19  1541
# 7           8     Darwin             Nunez   24    URU  24      16  1465
# 8           9   Ibrahima            Konate   24    FRA  18      13  1242
# 9          10      Diogo              Jota   27    POR  19      13  1047
# 10         11     Curtis             Jones   23    ENG  17      12   956
# 11         12        Joe             Gomez   26    ENG  21      11  1182
# 12         13       Cody             Gakpo   24    NED  23      10   975
# 13         14     Andrew         Robertson   29    SCO  12      10   954
# 14         15     Wataru              Endo   31    JPN  17      10   883
# 15         16       Joel             Matip   32    CMR  10       9   781
# 16         17       Ryan       Gravenberch   21    NED  18       8   768
# 17         18     Kostas          Tsimikas   27    GRE  11       8   665
# 18         19   Caoimhin          Kelleher   25    IRL   4       4   360
# 19         20     Jarell           Quansah   21    ENG   7       4   353
# 20         21     Harvey           Elliott   20    ENG  21       3   583
# 21         22      Conor           Bradley   20    NIR   3       3   231
# 22         23      Bobby             Clark   19    ENG   3       0    17
# 23         24        Ben              Doak   18    SCO   1       0    14
# 24         25       Owen              Beck   21    WAL   1       0     8
# 25         26     Thiago         Alcantara   32    ESP   1       0     6
# 26         27      James          McConell   19    ENG   2       0     2
# 27         28      Kaide            Gordon   19    ENG   1       0     1
# 28         29     Adrian          Castillo   37    ESP   0       0     0
# 29         30     Stefan          Bajcetic   19    ESP   0       0     0
# 30         31       Luke          Chambers   19    ENG   0       0     0
# 31         32      Lewis            Koumas   18    WAL   0       0     0
# 32         33     Fabian            Mrozek   20    POL   0       0     0
# 33         34       Trey             Nyoni   16    ENG   0       0     0
# 34         35    Marcelo          Pitaluga   21    BRA   0       0     0
# 35         36      Calum           Scanlon   19    ENG   0       0     0
#
#     full_match  goals  assist    pos  attack_point
# 0           21      0       0     GK             0
# 1           22      1       2     DF             3
# 2           20     15       9     FW            24
# 3           18      3       2     MF             5
# 4           18      2       4     DF             6
# 5           17      5       3     FW             8
# 6           17      2       1     MF             3
# 7           16      9       7     FW            16
# 8           14      0       0     DF             0
# 9           12      9       3     FW            12
# 10          11      1       1     MF             2
# 11          13      0       1     DF             1
# 12          11      4       3  FW,MF             7
# 13          11      1       0     DF             1
# 14          10      1       0     MF             1
# 15           9      0       0     DF             0
# 16           9      0       0     MF             0
# 17           7      0       3     DF             3
# 18           4      0       0     GK             0
# 19           4      0       0     DF             0
# 20           7      1       2  MF,FW             3
# 21           3      1       3     DF             4
# 22           0      0       0     MF             0
# 23           0      0       0     FW             0
# 24           0      0       0     DF             0
# 25           0      0       0     MF             0
# 26           0      0       0     MF             0
# 27           0      0       0     FW             0
# 28           0      0       0     GK             0
# 29           0      0       0     DF             0
# 30           0      0       0     DF             0
# 31           0      0       0     MF             0
# 32           0      0       0     GK             0
# 33           0      0       0     MF             0
# 34           0      0       0     GK             0
# 35           0      0       0     MF             0

# %%
df_1['player_name'] = df_1['first_name'] +' ' +  df_1['last_name']
df_1['player_name']

# %% [markdown]
# 팀의 핵심 선수 찾기

# %%
df_1['full_match'].sort_values()
df_1
# Out:
#     player_id first_name         last_name  age nation  mp  starts    Mt  \
# 0           1    Allison            Becker   31    BRA  21      21  1890
# 1           2     Virgil          Van Dijk   32    NED  23      23  2007
# 2           3    Mohamed             Salah   31    EGY  21      20  1786
# 3           4    Dominik        Szoboszlai   23    HUN  21      20  1657
# 4           5      Trent  Alexander-Arnold   25    ENG  21      19  1622
# 5           6       Luis              Diaz   27    COL  24      19  1568
# 6           7     Alexis      Mac Allister   25    ARG  20      19  1541
# 7           8     Darwin             Nunez   24    URU  24      16  1465
# 8           9   Ibrahima            Konate   24    FRA  18      13  1242
# 9          10      Diogo              Jota   27    POR  19      13  1047
# 10         11     Curtis             Jones   23    ENG  17      12   956
# 11         12        Joe             Gomez   26    ENG  21      11  1182
# 12         13       Cody             Gakpo   24    NED  23      10   975
# 13         14     Andrew         Robertson   29    SCO  12      10   954
# 14         15     Wataru              Endo   31    JPN  17      10   883
# 15         16       Joel             Matip   32    CMR  10       9   781
# 16         17       Ryan       Gravenberch   21    NED  18       8   768
# 17         18     Kostas          Tsimikas   27    GRE  11       8   665
# 18         19   Caoimhin          Kelleher   25    IRL   4       4   360
# 19         20     Jarell           Quansah   21    ENG   7       4   353
# 20         21     Harvey           Elliott   20    ENG  21       3   583
# 21         22      Conor           Bradley   20    NIR   3       3   231
# 22         23      Bobby             Clark   19    ENG   3       0    17
# 23         24        Ben              Doak   18    SCO   1       0    14
# 24         25       Owen              Beck   21    WAL   1       0     8
# 25         26     Thiago         Alcantara   32    ESP   1       0     6
# 26         27      James          McConell   19    ENG   2       0     2
# 27         28      Kaide            Gordon   19    ENG   1       0     1
# 28         29     Adrian          Castillo   37    ESP   0       0     0
# 29         30     Stefan          Bajcetic   19    ESP   0       0     0
# 30         31       Luke          Chambers   19    ENG   0       0     0
# 31         32      Lewis            Koumas   18    WAL   0       0     0
# 32         33     Fabian            Mrozek   20    POL   0       0     0
# 33         34       Trey             Nyoni   16    ENG   0       0     0
# 34         35    Marcelo          Pitaluga   21    BRA   0       0     0
# 35         36      Calum           Scanlon   19    ENG   0       0     0
#
#     full_match  goals  assist    pos  attack_point             player_name
# 0           21      0       0     GK             0          Allison Becker
# 1           22      1       2     DF             3         Virgil Van Dijk
# 2           20     15       9     FW            24           Mohamed Salah
# 3           18      3       2     MF             5      Dominik Szoboszlai
# 4           18      2       4     DF             6  Trent Alexander-Arnold
# 5           17      5       3     FW             8               Luis Diaz
# 6           17      2       1     MF             3     Alexis Mac Allister
# 7           16      9       7     FW            16            Darwin Nunez
# 8           14      0       0     DF             0         Ibrahima Konate
# 9           12      9       3     FW            12              Diogo Jota
# 10          11      1       1     MF             2            Curtis Jones
# 11          13      0       1     DF             1               Joe Gomez
# 12          11      4       3  FW,MF             7              Cody Gakpo
# 13          11      1       0     DF             1        Andrew Robertson
# 14          10      1       0     MF             1             Wataru Endo
# 15           9      0       0     DF             0              Joel Matip
# 16           9      0       0     MF             0        Ryan Gravenberch
# 17           7      0       3     DF             3         Kostas Tsimikas
# 18           4      0       0     GK             0       Caoimhin Kelleher
# 19           4      0       0     DF             0          Jarell Quansah
# 20           7      1       2  MF,FW             3          Harvey Elliott
# 21           3      1       3     DF             4           Conor Bradley
# 22           0      0       0     MF             0             Bobby Clark
# 23           0      0       0     FW             0                Ben Doak
# 24           0      0       0     DF             0               Owen Beck
# 25           0      0       0     MF             0        Thiago Alcantara
# 26           0      0       0     MF             0          James McConell
# 27           0      0       0     FW             0            Kaide Gordon
# 28           0      0       0     GK             0         Adrian Castillo
# 29           0      0       0     DF             0         Stefan Bajcetic
# 30           0      0       0     DF             0           Luke Chambers
# 31           0      0       0     MF             0            Lewis Koumas
# 32           0      0       0     GK             0           Fabian Mrozek
# 33           0      0       0     MF             0              Trey Nyoni
# 34           0      0       0     GK             0        Marcelo Pitaluga
# 35           0      0       0     MF             0           Calum Scanlon

# %%
top_10_by_time = df_1.sort_values(by='Mt', ascending=False).head(10)
top_10_by_time

# 데이터 시각화
plt.figure(figsize=(12, 8))
sns.barplot(x = 'Mt', y = 'player_name', data = top_10_by_time)
plt.title('Top 10 Players by Minutes Played', fontsize=16)
plt.xlabel('Minutes Played')
plt.ylabel('Player name')

plt.savefig('../images/1_minutes_played.png')
plt.show()

# %%
top_attackers = df_1[df_1['attack_point'] > 0].sort_values(by='attack_point', ascending= False).head(10)

plot_data = top_attackers[['player_name', 'goals', 'assist']].set_index('player_name')
plot_data.plot(kind = 'bar', stacked = True, figsize = (12, 8), colormap='viridis')
plt.title('Top 10 Offensive Contributors (Goals + Assists)', fontsize = 16)
plt.ylabel('Count')
plt.xticks(rotation = 45)

plt.savefig('../images/2_top_attacker.png')
plt.show()

# %%
df_1['age'].describe()
# Out:
# count    36.000000
# mean     24.027778
# std       5.179554
# min      16.000000
# 25%      19.750000
# 50%      23.500000
# 75%      27.000000
# max      37.000000
# Name: age, dtype: float64

# %%
sns.histplot(df_1['age'], bins = 10,kde = True)
plt.title('Squad Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number Of Player')

plt.savefig('../images/3_squad_age_distribution.png')
plt.show()

# %%
df_1['nation'].value_counts()
# Out:
# nation
# ENG    11
# ESP     3
# NED     3
# WAL     2
# BRA     2
# SCO     2
# EGY     1
# ARG     1
# URU     1
# COL     1
# HUN     1
# POR     1
# FRA     1
# JPN     1
# CMR     1
# IRL     1
# GRE     1
# NIR     1
# POL     1
# Name: count, dtype: int64

# %%
plt.pie(df_1['nation'].value_counts())
plt.title('Player Nationality Distribution')
plt.show()
